# %% [markdown]
# ### Calculating vertebrate gut microbiome alpha diversity for the Groussin and the Song datasets. Then run regressions on all vertebrate datasets

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.simplefilter('ignore')
import qiime2 as q2

# %% [markdown]
# ### Load the  Groussin Data

# %%
GenPath='...'

# %%
otus = pd.read_csv(GenPath+'/Groussin_data/otuTable_44444uniqSeqs.txt', sep = "\t")

# %%
otus = otus.set_index('sample')
otus.head()
# Out:
#            BlackRhino1_1137430*size=2*  ZebraSTL1_1300880*size=1*  \
# sample
# AfElphSD3                            0                          0
# Armadillo                            0                          0
# BaboonSTL                            0                          0
# BigHornSD                            0                          0
# BlackBr2                             0                          0
#
#            Giraffe2_1140929*size=1*  Gazelle3_1140525*size=9*  \
# sample
# AfElphSD3                         0                         0
# Armadillo                         0                         0
# BaboonSTL                         0                         0
# BigHornSD                         0                         1
# BlackBr2                          0                         0
#
#            Giraffe2_1145120*size=2*  Okapi2_1097870*size=1*  \
# sample
# AfElphSD3                         0                       0
# Armadillo                         0                       0
# BaboonSTL                         0                       0
# BigHornSD                         0                       0
# BlackBr2                          0                       0
#
#            Gazelle3_1138247*size=1*  Gazelle3_1120629*size=1*  \
# sample
# AfElphSD3                         0                         0
# Armadillo                         0                         0
# BaboonSTL                         0                         0
# BigHornSD                         0                         0
# BlackBr2                          0                         0
#
#            Gazelle3_1215385*size=4*  ZebraSTL1_1162298*size=3*  ...  \
# sample                                                          ...
# AfElphSD3                         0                          0  ...
# Armadillo                         0                          0  ...
# BaboonSTL                         0                          0  ...
# BigHornSD                         2                          0  ...
# BlackBr2                          0                          0  ...
#
#            Chimp1_1231977*size=3*  Chimp1_1245120*size=1*  \
# sample
# AfElphSD3                       0                       0
# Armadillo                       0                       0
# BaboonSTL                       0                       0
# BigHornSD                       0                       0
# BlackBr2                        0                       0
#
#            Orang1_1037687*size=1*  Orang1_1245894*size=3*  \
# sample
# AfElphSD3                       0                       0
# Armadillo                       0                       0
# BaboonSTL                       0                       0
# BigHornSD                       0                       0
# BlackBr2                        0                       0
#
#            Chimp1_1113691*size=1*  GorillaSTL_1193612*size=1*  \
# sample
# AfElphSD3                       0                           0
# Armadillo                       0                           0
# BaboonSTL                       0                           0
# BigHornSD                       0                           0
# BlackBr2                        0                           0
#
#            GorillaSTL_1260380*size=2*  RTLemur_1302590*size=1*  \
# sample
# AfElphSD3                           0                        0
# Armadillo                           0                        0
# BaboonSTL                           0                        0
# BigHornSD                           0                        0
# BlackBr2                            0                        0
#
#            Chimp1_1282036*size=1*  GorillaSTL_1115335*size=1*
# sample
# AfElphSD3                       0                           0
# Armadillo                       0                           0
# BaboonSTL                       0                           0
# BigHornSD                       0                           0
# BlackBr2                        0                           0
#
# [5 rows x 44444 columns]

# %%
# Import the table so it can be saved as an artifact
table = q2.Artifact.import_data("FeatureTable[Frequency]", otus)
table.save(GenPath+'Groussin_data/diversity/feature_table.qza')

# %% [markdown]
# ### Rarefy the otu table

# %%
# Take my otu table that I've already imported and summarize it 
# !qiime feature-table summarize \
    --i-table .../Groussin_data/diversity/feature_table.qza \
    --o-visualization .../Groussin_data/diversity/FTsummary.qzv

# %%
# Visualized the summary, will be continuing with rarefying to 1266
# !qiime feature-table rarefy \
    --i-table .../Groussin_data/diversity/feature_table.qza \
    --p-sampling-depth 1266 \
    --o-rarefied-table .../Groussin_data/diversity/rarefiedFT.qza

# %%
! qiime diversity alpha \
    --i-table .../Groussin_data/diversity/rarefiedFT.qza \
    --p-metric simpson \
    --o-alpha-diversity .../Groussin_data/diversity/simpson.qza

# %% [markdown]
# ### Repeat this process for the Song et al. data provided by Florent Mazel, which has already been filtered according to the paper **Transmission mode and dispersal traits correlated with host specificity in mammalian gut microbes**

# %%
## Import song data 
song_metadata = pd.read_csv(GenPath+'/Flo_data/Song_Metadata.txt', sep = ' ')
song_metadata.head()
# Out:
#        SampleID  studyID  deblurred_seqs        pd_5k   shannon_5k  \
# 1  X11212.AC673    11212           43494  34.21504159  6.546511187
# 2  X11212.AC674    11212           40022  39.34137459  6.747977045
# 3  X11212.AC679    11212           17199  43.65041219  6.803884218
# 4  X11212.AC680    11212           25815  33.68887383  6.790575961
# 5  X11212.AC683    11212           26953  40.57833243  6.736080096
#
#   sample_type preservative      sex  healthy captive_wild  ...  \
# 1       fecal         etoh  unknown  unknown         wild  ...
# 2       fecal         etoh  unknown  unknown         wild  ...
# 3       fecal         etoh  unknown  unknown         wild  ...
# 4       fecal         etoh  unknown  unknown         wild  ...
# 5       fecal         etoh  unknown  unknown         wild  ...
#
#   initial_fastq_name           dada2_output_names          Other  \
# 1     11212.AC673.gz  11212.AC673.gz_F_filt.fastq  _F_filt.fastq
# 2     11212.AC674.gz  11212.AC674.gz_F_filt.fastq  _F_filt.fastq
# 3     11212.AC679.gz  11212.AC679.gz_F_filt.fastq  _F_filt.fastq
# 4     11212.AC680.gz  11212.AC680.gz_F_filt.fastq  _F_filt.fastq
# 5     11212.AC683.gz  11212.AC683.gz_F_filt.fastq  _F_filt.fastq
#
#   duplicated_sample is_sub_species Species_name_Corresponding  \
# 1             False          False                    unknown
# 2             False          False                    unknown
# 3             False          False                    unknown
# 4             False          False                    unknown
# 5             False          False                    unknown
#
#   Time_Tree_curated     Order    Family       Diet
# 1   Alouatta_caraya  Primates  Atelidae  herbivore
# 2   Alouatta_caraya  Primates  Atelidae  herbivore
# 3   Alouatta_caraya  Primates  Atelidae  herbivore
# 4   Alouatta_caraya  Primates  Atelidae  herbivore
# 5   Alouatta_caraya  Primates  Atelidae  herbivore
#
# [5 rows x 123 columns]

# %%
song_asvs = pd.read_csv(GenPath+'/Flo_data/Song_ASVs_counts_filt.txt', sep = ' ')
song_asvs = song_asvs.transpose()
song_asvs.head()
# Out:
#              ASV_1  ASV_2  ASV_3  ASV_4  ASV_5  ASV_6  ASV_7  ASV_8  ASV_9  \
# 11212.AC673      0      0      0      0      0      0      0      0      0
# 11212.AC674      0      0      0      0      0      0      0      0      0
# 11212.AC679     57      0      0      0      0      0      0      0      0
# 11212.AC680      0      0      0      0      0      0      0      0      0
# 11212.AC683      0      0      0      0      0      0      0      0      0
#
#              ASV_10  ...  ASV_52655  ASV_52657  ASV_52709  ASV_52727  \
# 11212.AC673       0  ...          0          0          0          0
# 11212.AC674       0  ...          0          0          0          0
# 11212.AC679       0  ...          0          0          0          0
# 11212.AC680       0  ...          0          0          0          0
# 11212.AC683       0  ...          0          0          0          0
#
#              ASV_52912  ASV_53147  ASV_53156  ASV_53158  ASV_53160  ASV_53161
# 11212.AC673          0          0          0          0          0          0
# 11212.AC674          0          0          0          0          0          0
# 11212.AC679          0          0          0          0          0          0
# 11212.AC680          0          0          0          0          0          0
# 11212.AC683          0          0          0          0          0          0
#
# [5 rows x 29057 columns]

# %%
table = q2.Artifact.import_data('FeatureTable[Frequency]', song_asvs)
table.save(GenPath+'/Flo_data/diversity/song_table.qza')

# %%
# !qiime feature-table summarize \
    --i-table .../Flo_data/diversity/song_table.qza \
    --o-visualization .../Flo_data/diversity/song_summary.qzv

# %%
# !qiime feature-table rarefy \
    --i-table ...Flo_data/diversity/song_table.qza \
    --p-sampling-depth 5035 \
    --o-rarefied-table /proj.../Flo_data/diversity/song_table_rare.qza \

# %%
! qiime diversity alpha \
--i-table .../Flo_data/diversity/song_table_rare.qza \
--p-metric simpson \
--o-alpha-diversity .../Flo_data/diversity/song_simpson.qza

# %%
song_simpson = pd.read_csv(GenPath+'/Flo_data/diversity/song_simpson/data/alpha-diversity.tsv', sep = '\t')
song_simpson=song_simpson.rename(columns = {'Unnamed: 0':'SampleID'})
song_simpson.head()
# Out:
#       SampleID   simpson
# 0  11212.AC673  0.973291
# 1  11212.AC674  0.972535
# 2  11212.AC679  0.972370
# 3  11212.AC680  0.973233
# 4  11212.AC683  0.975682

# %% [markdown]
# ### In our dataset, the sampleIDs in the ASV table don't have 'X' in front, so we will be adding that back in so we can merge with the metadata later

# %%
song_simpson['SampleID'] = song_simpson.SampleID.apply(lambda x: 'X'+ x)
song_simpson.head()
# Out:
#        SampleID   simpson
# 0  X11212.AC673  0.973291
# 1  X11212.AC674  0.972535
# 2  X11212.AC679  0.972370
# 3  X11212.AC680  0.973233
# 4  X11212.AC683  0.975682

# %%
song_metadata = pd.read_csv(GenPath+'/Flo_data/Song_Metadata.txt', sep = ' ')[['SampleID', 'ET.BodyMass.Value']]
song_metadata.head()
# Out:
#        SampleID  ET.BodyMass.Value
# 1  X11212.AC673            5862.46
# 2  X11212.AC674            5862.46
# 3  X11212.AC679            5862.46
# 4  X11212.AC680            5862.46
# 5  X11212.AC683            5862.46

# %%
song_diversity = pd.merge(song_simpson, song_metadata, on = 'SampleID')
song_diversity.head()
# Out:
#        SampleID   simpson  ET.BodyMass.Value
# 0  X11212.AC673  0.973291            5862.46
# 1  X11212.AC674  0.972535            5862.46
# 2  X11212.AC679  0.972370            5862.46
# 3  X11212.AC680  0.973233            5862.46
# 4  X11212.AC683  0.975682            5862.46

# %%
# Convert body massses from being presented in grams to kilograms
song_diversity['body_mass_kg'] = song_diversity['ET.BodyMass.Value'].apply(lambda x: x/1000)

# %%
song_diversity.head()
# Out:
#        SampleID   simpson  ET.BodyMass.Value  body_mass_kg
# 0  X11212.AC673  0.973291            5862.46       5.86246
# 1  X11212.AC674  0.972535            5862.46       5.86246
# 2  X11212.AC679  0.972370            5862.46       5.86246
# 3  X11212.AC680  0.973233            5862.46       5.86246
# 4  X11212.AC683  0.975682            5862.46       5.86246

# %% [markdown]
# ### Groussin data wrangling

# %%
# Load in the shannon_diversity data that I generated (note: artifacts were unzipped in the terminal outside of this nb)
grous_simpson = pd.read_csv(GenPath+'Groussin_data/diversity/simpson/data/alpha-diversity.tsv', sep = '\t').rename(columns={'Unnamed: 0': 'SampleID'})
grous_simpson.head()
# Out:
#     SampleID   simpson
# 0  AfElphSD3  0.994633
# 1  Armadillo  0.991125
# 2  BaboonSTL  0.954364
# 3  BigHornSD  0.996792
# 4   BlackBr2  0.465413

# %%
grous_masses = pd.read_csv(GenPath+'/Groussin_data/Groussin_MammallianGutsMassTable.csv')\
    [['SampleID', 'Mean_Mass(kg)']].rename(columns = {'Mean_Mass(kg)': 'body_mass_kg'}).dropna()

grous_masses = grous_masses.drop_duplicates().reset_index(drop=True)

grous_masses
# Out:
#        SampleID  body_mass_kg
# 0     AfElphSD4   4035.000000
# 1     Armadillo      1.200000
# 2     BaboonSTL     18.000000
# 3     BigHornSD     67.130000
# 4      BlackBr2    175.000000
# 5    BlackLemur      2.040000
# 6   BlackRhino1    986.575000
# 7      BushDog1      5.500000
# 8   Callimicos       0.557000
# 9      Capybara     55.000000
# 10       Chimp1     61.065000
# 11      Colobus     10.281250
# 12      Echidna      3.430000
# 13     Gazelle3     12.750000
# 14     Giraffe2   1175.000000
# 15   GorillaSTL    150.987500
# 16       Horse1    250.000000
# 17       Hyena2     62.370000
# 18     HyraxSTL      0.930000
# 19        Kroo3     44.841000
# 20        Lion1     84.000000
# 21       Okapi2    250.000000
# 22       Orang1     54.229040
# 23     PolarBr2    258.285000
# 24      RTLemur      2.800000
# 25       Rabbit      1.894333
# 26         Saki      1.750000
# 27      SpecBr2    104.250000
# 28       SpgbkW     39.000000
# 29     Squirrel      0.415667
# 30       Urial2     61.000000
# 31        VWPig     30.000000
# 32    ZebraSTL1    385.800000

# %%
grous_diversity = pd.merge(grous_simpson, grous_masses, on = 'SampleID')
grous_diversity
# Out:
#        SampleID   simpson  body_mass_kg
# 0     Armadillo  0.991125      1.200000
# 1     BaboonSTL  0.954364     18.000000
# 2     BigHornSD  0.996792     67.130000
# 3      BlackBr2  0.465413    175.000000
# 4    BlackLemur  0.870901      2.040000
# 5   BlackRhino1  0.990151    986.575000
# 6      BushDog1  0.961254      5.500000
# 7      Capybara  0.994032     55.000000
# 8        Chimp1  0.996899     61.065000
# 9       Colobus  0.991692     10.281250
# 10     Gazelle3  0.997375     12.750000
# 11     Giraffe2  0.996877   1175.000000
# 12   GorillaSTL  0.979414    150.987500
# 13       Horse1  0.997842    250.000000
# 14       Hyena2  0.991340     62.370000
# 15     HyraxSTL  0.995281      0.930000
# 16        Kroo3  0.997580     44.841000
# 17        Lion1  0.920348     84.000000
# 18       Okapi2  0.997887    250.000000
# 19       Orang1  0.996001     54.229040
# 20     PolarBr2  0.911514    258.285000
# 21      RTLemur  0.995571      2.800000
# 22       Rabbit  0.983553      1.894333
# 23         Saki  0.991608      1.750000
# 24      SpecBr2  0.773812    104.250000
# 25       SpgbkW  0.998404     39.000000
# 26     Squirrel  0.627790      0.415667
# 27       Urial2  0.998252     61.000000
# 28        VWPig  0.988170     30.000000
# 29    ZebraSTL1  0.981637    385.800000

# %%
grous_diversity['dataset'] = 'Groussin et al'
song_diversity['dataset'] = 'Song et al'

# %%
full_diversity = pd.concat([grous_diversity, song_diversity[['SampleID', 'simpson', 'body_mass_kg', 'dataset']]])
full_diversity.head()
# Out:
#      SampleID   simpson  body_mass_kg         dataset
# 0   Armadillo  0.991125          1.20  Groussin et al
# 1   BaboonSTL  0.954364         18.00  Groussin et al
# 2   BigHornSD  0.996792         67.13  Groussin et al
# 3    BlackBr2  0.465413        175.00  Groussin et al
# 4  BlackLemur  0.870901          2.04  Groussin et al

# %% [markdown]
# ### Qiime2 returns Simpson as 1-D and I need 1/D. I am going to generate this value by applying the formula: QiimeSimp = 1 - D, therefore D = 1 - QiimeSimp, so to get 1/D I will do: SimpDom = 1/(1-QiimeSimp)

# %%
full_diversity['inv_simpson'] = full_diversity.simpson.apply(lambda x: 1/(1-x))
full_diversity.head()
# Out:
#      SampleID   simpson  body_mass_kg         dataset  inv_simpson
# 0   Armadillo  0.991125          1.20  Groussin et al   112.679696
# 1   BaboonSTL  0.954364         18.00  Groussin et al    21.912337
# 2   BigHornSD  0.996792         67.13  Groussin et al   311.698950
# 3    BlackBr2  0.465413        175.00  Groussin et al     1.870604
# 4  BlackLemur  0.870901          2.04  Groussin et al     7.746001

# %%
full_diversity.SampleID.nunique()
# Out:
# 1403

# %%
# Save to csv
full_diversity.to_csv(GenPath+'/output/Song_Groussin_diversity.csv')
